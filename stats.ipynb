# %%
import pandas as pd

# %%
users_visits = pd.read_excel('user_visits.xlsx')
print(users_visits_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 users_visits = pd.read_excel('user_visits.xlsx')
# ----> 2 print(users_visits_)
#
# NameError: name 'users_visits_' is not defined

# %%
october_data = users_visits[(users_visits['date'] > '2013-01-01') & (users_visits['date'] < '2013-02-01')]
