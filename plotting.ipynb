# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
stats = pd.read_csv("totals.csv")
months = stats["Month"].tolist()

# %%
plt.figure()
stats.plot()
plt.xticks([0,1,2],[months])
plt.xticks(rotation=45)
plt.legend(loc='best')
